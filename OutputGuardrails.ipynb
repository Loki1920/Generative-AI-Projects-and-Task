# %%
# !pip install guardrails-ai
# Out:
# Requirement already satisfied: guardrails-ai in /usr/local/lib/python3.10/dist-packages (0.4.5)
# Requirement already satisfied: coloredlogs<16.0.0,>=15.0.1 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (15.0.1)
# Requirement already satisfied: griffe<0.37.0,>=0.36.9 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (0.36.9)
# Requirement already satisfied: guardrails-api-client<0.3.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (0.2.1)
# Requirement already satisfied: jwt<2.0.0,>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (1.3.1)
# Requirement already satisfied: langchain-core<0.3,>=0.1 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (0.2.9)
# Requirement already satisfied: lxml<5.0.0,>=4.9.3 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (4.9.4)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (3.8.1)
# Requirement already satisfied: openai<2.0.0,>=1.30.1 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (1.35.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.24.0 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (1.25.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.24.0 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (1.25.0)
# Requirement already satisfied: pip>=22 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (23.1.2)
# Requirement already satisfied: pydantic<3.0,>=1.10.9 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (2.7.3)
# Requirement already satisfied: pydash<8.0.0,>=7.0.6 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (7.0.7)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (2.8.2)
# Requirement already satisfied: regex<2024.0.0,>=2023.10.3 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (2023.12.25)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (2.31.0)
# Requirement already satisfied: rich<14.0.0,>=13.6.0 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (13.7.1)
# Requirement already satisfied: rstr<4.0.0,>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (3.2.2)
# Requirement already satisfied: tenacity>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (8.3.0)
# Requirement already satisfied: tiktoken>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (0.7.0)
# Collecting typer[all]<0.10.0,>=0.9.0 (from guardrails-ai)
#   Using cached typer-0.9.4-py3-none-any.whl (45 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (4.12.2)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs<16.0.0,>=15.0.1->guardrails-ai) (10.0)
# Requirement already satisfied: colorama>=0.4 in /usr/local/lib/python3.10/dist-packages (from griffe<0.37.0,>=0.36.9->guardrails-ai) (0.4.6)
# Requirement already satisfied: httpx<0.28.0,>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from guardrails-api-client<0.3.0,>=0.2.1->guardrails-ai) (0.27.0)
# Requirement already satisfied: attrs>=21.3.0 in /usr/local/lib/python3.10/dist-packages (from guardrails-api-client<0.3.0,>=0.2.1->guardrails-ai) (23.2.0)
# Requirement already satisfied: cryptography!=3.4.0,>=3.1 in /usr/local/lib/python3.10/dist-packages (from jwt<2.0.0,>=1.3.1->guardrails-ai) (42.0.8)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.1->guardrails-ai) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.1->guardrails-ai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.1->guardrails-ai) (0.1.81)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.1->guardrails-ai) (24.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->guardrails-ai) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->guardrails-ai) (1.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->guardrails-ai) (4.66.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.30.1->guardrails-ai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.30.1->guardrails-ai) (1.7.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.30.1->guardrails-ai) (1.3.1)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0->guardrails-ai) (1.2.14)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0->guardrails-ai) (1.63.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0->guardrails-ai) (1.64.1)
# Requirement already satisfied: opentelemetry-api~=1.15 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0->guardrails-ai) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.25.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0->guardrails-ai) (1.25.0)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0->guardrails-ai) (1.25.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-proto==1.25.0->opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0->guardrails-ai) (3.20.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-sdk<2.0.0,>=1.24.0->guardrails-ai) (0.46b0)
# Requirement already satisfied: importlib-metadata<=7.1,>=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api~=1.15->opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0->guardrails-ai) (7.1.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0,>=1.10.9->guardrails-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0,>=1.10.9->guardrails-ai) (2.18.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.8.2->guardrails-ai) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->guardrails-ai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->guardrails-ai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->guardrails-ai) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->guardrails-ai) (2024.6.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.6.0->guardrails-ai) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.6.0->guardrails-ai) (2.16.1)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]<0.10.0,>=0.9.0->guardrails-ai) (1.5.4)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.30.1->guardrails-ai) (1.2.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography!=3.4.0,>=3.1->jwt<2.0.0,>=1.3.1->guardrails-ai) (1.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.6->opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0->guardrails-ai) (1.14.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.20.0->guardrails-api-client<0.3.0,>=0.2.1->guardrails-ai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.20.0->guardrails-api-client<0.3.0,>=0.2.1->guardrails-ai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1->guardrails-ai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1->guardrails-ai) (3.10.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.6.0->guardrails-ai) (0.1.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography!=3.4.0,>=3.1->jwt<2.0.0,>=1.3.1->guardrails-ai) (2.22)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=7.1,>=6.0->opentelemetry-api~=1.15->opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0->guardrails-ai) (3.19.2)
# Installing collected packages: typer
#   Attempting uninstall: typer
#     Found existing installation: typer 0.12.3
#     Uninstalling typer-0.12.3:
#       Successfully uninstalled typer-0.12.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastapi-cli 0.0.4 requires typer>=0.12.3, but you have typer 0.9.4 which is incompatible.
# Successfully installed typer-0.9.4

# %% [markdown]
# ##Hallucination/Fact checking

# %%
# !guardrails hub install hub://guardrails/wiki_provenance
# Out:
# Installing hub://guardrails/wiki_provenance...
# [  ==] Fetching manifest
# [    ] Downloading dependencies  Running command git clone --filter=blob:none --quiet https://github.com/guardrails-ai/wiki_provenance.git /tmp/pip-req-build-cm2060r2
# [   =] Downloading dependenciesWARNING: Target directory /usr/local/lib/python3.10/dist-packages/guardrails/hub/guardrails/wiki_provenance/wiki_provenance-0.0.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /usr/local/lib/python3.10/dist-packages/guardrails/hub/guardrails/wiki_provenance/validator already exists. Specify --upgrade to force replacement.
# [ ===] Downloading dependencies
# [    ] Running post-install setupERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# guardrails-ai 0.4.5 requires typer[all]<0.10.0,>=0.9.0, but you have typer 0.12.3 which is incompatible.
# [=   ] Running post-install setup
# ✅Successfully installed guardrails/wiki_provenance!
#
#
# Import validator:
# from guardrails.hub import WikiProvenance
#
# Get more info:
# https://hub.guardrailsai.com/validator/guardrails/wiki_provenance

# %%
import os

# Set the environment variable for OpenAI API key
os.environ['OPENAI_API_KEY'] = ''

# %%
# Import Guard and Validator
from guardrails.hub import WikiProvenance
from guardrails import Guard

# Use the Guard with the validator
guard = Guard().use(
    WikiProvenance,
    topic_name="Apple company",
    validation_method="sentence",
    llm_callable="gpt-3.5-turbo",
    on_fail="exception"
)

# Test passing response
guard.validate("Apple was founded by Steve Jobs in April 1976.", metadata={"pass_on_invalid": True})  # Pass

# Test failing response
try:
    guard.validate("Ratan Tata founded Apple in September 1998 as a fruit selling company.")  # Fail
except Exception as e:
    print(e)
# Out:
# /usr/local/lib/python3.10/dist-packages/guardrails/validators/__init__.py:51: FutureWarning:
#     Importing validators from `guardrails.validators` is deprecated.
#     All validators are now available in the Guardrails Hub. Please install
#     and import them from the hub instead. All validators will be
#     removed from this module in the next major release.
#
#     Install with: `guardrails hub install hub://<namespace>/<validator_name>`
#     Import as: from guardrails.hub import `ValidatorName`
#
#   warn(
# Search results:
#  ['Apple Inc.', 'Gold Apple (company)', 'Apple Store']
#
# Validation response:
#  yes
#
# Validation response:
#  no
# Validation failed for field with errors: None of the following sentences in the response are supported by the provided context:
# - Ratan Tata founded Apple in September 1998 as a fruit selling company.

# %%
# Import necessary modules and validators
from guardrails.hub import WikiProvenance
from guardrails import Guard

class FactValidator:
    def __init__(self, topic, model, method):
        """
        Initialize the FactValidator with a specific topic and model.

        Args:
            topic (str): Topic name for the WikiProvenance validator.
            model (str): Language model callable, e.g., 'gpt-3.5-turbo'.
            method (str): Validation method, e.g., 'sentence'.
        """
        self.topic = topic
        self.model = model
        self.method = method
        self.guard = self.setup_guard()

    def setup_guard(self):
        """
        Setup and configure the Guard object with the WikiProvenance validator.

        Returns:
            Guard: Configured Guard object.
        """
        guard = Guard().use(
            WikiProvenance,
            topic_name=self.topic,
            validation_method=self.method,
            llm_callable=self.model,
            on_fail="exception"
        )
        return guard

    def validate_sentence(self, sentence):
        """
        Validate a sentence using the configured Guard object.

        Args:
            sentence (str): The sentence to be validated.

        Returns:
            str: Validation result message.
        """
        try:
            result = self.guard.validate(sentence, metadata={"pass_on_invalid": True})
            return "Validation passed: " + sentence
        except Exception as e:
            return f"Validation failed: {str(e)}"

# Main function to test the functionality
def main():
    validator = FactValidator("Apple company", "gpt-3.5-turbo", "sentence")
    print(validator.validate_sentence("Apple was founded by Steve Jobs in April 1976."))
    print(validator.validate_sentence("Ratan Tata founded Apple in September 1998 as a fruit selling company."))

# Run the main function if this script is executed
if __name__ == "__main__":
    main()
# Out:
# Search results:
#  ['Apple Inc.', 'Gold Apple (company)', 'Apple Store']
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID:
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 106-4981137371163477988
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 107-5131005205115159576
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 108--3266649708919197942
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 109-3145836581776155265
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 110-194581175089876559
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 111-4656678754432468993
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 112--6627774511727351707
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 113--6507383823806299621
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 114-6054092162930560990
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 115--672937039001239844
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 116--7024640818265330808
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 117-8313384157043748969
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 118--8454406093842829581
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 119--7657556531391344538
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 120-8276131509045811707
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 121-7158075594239483447
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 122--689719700715021330
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 123-7686822796223127144
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 124--2581879660867051268
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 125-72695122334659748
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 126-8897595583557125033
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 127--4347149234312640375
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 128-640510783895569867
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 129--3741845912422089234
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 130-7884834939735540928
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 131-7961357466614130654
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 132--5044419580831107274
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 133--5090380625226208270
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 134--3513817734107736657
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 135-7047238639597027535
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 136--8106712239348015248
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 137--1894588805123432159
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 138--558111170182306903
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 139-6817915276712229286
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 140--6532465810939766505
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 141-7523147437223103107
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 142--8481141576586298108
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 143--6955426172812019326
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 144-6291970478536221746
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 145-2471272349856462915
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 146--2312183336592728521
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 147-571511737617853687
# Validation response:
#  yes
# Validation passed: Apple was founded by Steve Jobs in April 1976.
#
# Validation response:
#  no
# Validation failed: Validation failed for field with errors: None of the following sentences in the response are supported by the provided context:
# - Ratan Tata founded Apple in September 1998 as a fruit selling company.

# %% [markdown]
# ##Syntax check/Valid Python

# %%
# !guardrails hub install hub://reflex/valid_python
# Out:
# Installing hub://reflex/valid_python...
# [   =] Fetching manifest
# [    ] Downloading dependencies  Running command git clone --filter=blob:none --quiet https://github.com/reflex-dev/valid_python_validator.git /tmp/pip-req-build-xuvq89vl
# [==  ] Downloading dependencies
# [    ] Running post-install setup
# ✅Successfully installed reflex/valid_python!
#
#
# Import validator:
# from guardrails.hub import ValidPython
#
# Get more info:
# https://hub.guardrailsai.com/validator/reflex/valid_python

# %%
# Import Guard and Validator
from guardrails.hub import ValidPython
from guardrails import Guard

# Setup Guard
guard = Guard().use(ValidPython, on_fail="exception")

# Correct python
correct_python = """
import os

def foo():
    print(f"Current path is: {os.getcwd()}")

foo()
"""

incorrect_python = """
import os

def foo()
    print f"Current path is: {os.getcwd()}"

foo()
"""

guard.validate(correct_python)  # Validator passes
try:
    guard.validate(incorrect_python)  # Validator fails
except Exception as e:
    print(e)
# Out:
# /usr/local/lib/python3.10/dist-packages/guardrails/validators/__init__.py:51: FutureWarning:
#     Importing validators from `guardrails.validators` is deprecated.
#     All validators are now available in the Guardrails Hub. Please install
#     and import them from the hub instead. All validators will be
#     removed from this module in the next major release.
#
#     Install with: `guardrails hub install hub://<namespace>/<validator_name>`
#     Import as: from guardrails.hub import `ValidatorName`
#
#   warn(
# Validation failed for field with errors: Syntax error: expected ':'

# %% [markdown]
# ##Wrap the code inside functions and make it callable/skeleton code

# %%
# Import necessary libraries
from guardrails.hub import ValidPython
from guardrails import Guard

class CodeValidator:
    """A class to handle Python code validation using Guard and ValidPython."""

    def __init__(self):
        """Initialize the CodeValidator with a Guard object configured with ValidPython."""
        self.guard = self.setup_guard()

    def setup_guard(self):
        """Set up and return the Guard object configured with ValidPython validator."""
        return Guard().use(ValidPython, on_fail="exception")

    def validate_code(self, code):
        """Validate the given Python code using the Guard object.

        Args:
            code (str): The Python code snippet to validate.

        Returns:
            str: A success message if validation passes.

        Raises:
            Exception: If validation fails, with a custom error message.
        """
        try:
            self.guard.validate(code)  # Validator attempts to validate the code
            return "Python code is valid."
        except Exception as e:
            raise Exception(f"Custom Error Message: Validation of the provided Python code failed. Error: {e}")

def main():
    """Main function to create a CodeValidator instance and validate code snippets."""
    # Create an instance of CodeValidator
    validator = CodeValidator()

    # Correct Python code
    correct_python = """
import os

def foo():
    print(f"Current path is: {os.getcwd()}")

foo()
    """

    # Incorrect Python code
    incorrect_python = """
import os

def foo()
    print f"Current path is: {os.getcwd()}"

foo()
    """

    # Validate correct Python code
    try:
        result = validator.validate_code(correct_python)
        print(result)
    except Exception as e:
        print(e)

    # Validate incorrect Python code
    try:
        result = validator.validate_code(incorrect_python)
        print(result)
    except Exception as e:
        print(e)

# Call the main function to validate the snippets
if __name__ == "__main__":
    main()
# Out:
# Python code is valid.
# Custom Error Message: Validation of the provided Python code failed. Error: Validation failed for field with errors: Syntax error: expected ':'

# %% [markdown]
# ##Moderation Guardrails

# %%
# !guardrails hub install hub://guardrails/toxic_language
# Out:
# Installing hub://guardrails/toxic_language...
# [====] Fetching manifest
# [    ] Downloading dependencies  Running command git clone --filter=blob:none --quiet https://github.com/guardrails-ai/toxic_language.git /tmp/pip-req-build-g47szcgw
# [==  ] Downloading dependencies
# [====] Running post-install setupDownloading: "https://github.com/unitaryai/detoxify/releases/download/v0.1.2/unbiased-albert-c8519128.ckpt" to /root/.cache/torch/hub/checkpoints/unbiased-albert-c8519128.ckpt
# 100% 44.6M/44.6M [01:45<00:00, 443kB/s]
# [=== ] Running post-install setup/usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json: 100% 684/684 [00:00<00:00, 3.09MB/s]
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 111kB/s]
# spiece.model: 100% 760k/760k [00:00<00:00, 2.31MB/s]
# tokenizer.json: 100% 1.31M/1.31M [00:00<00:00, 4.01MB/s]
# [=   ] Running post-install setup
# ✅Successfully installed guardrails/toxic_language!
#
#
# Import validator:
# from guardrails.hub import ToxicLanguage
#
# Get more info:
# https://hub.guardrailsai.com/validator/guardrails/toxic_language

# %%
# Import Guard and Validator
from guardrails.hub import ToxicLanguage
from guardrails import Guard

# Use the Guard with the validator
guard = Guard().use(
    ToxicLanguage, threshold=0.5, validation_method="sentence", on_fail="exception"
)

# Test passing response
guard.validate("Love how you think and attack the problem. Great job!")

try:
    # Test failing response
    guard.validate(
        "Please look carefully. You are a stupid idiot who can't do anything right."
    )
except Exception as e:
    print(e)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Validation failed for field with errors: The following sentences in your response were found to be toxic:
#
# - You are a stupid idiot who can't do anything right.

# %%
# Import necessary modules and validators
from guardrails.hub import ToxicLanguage
from guardrails import Guard

class ToxicLanguageValidator:
    def __init__(self, threshold=0.5, validation_method="sentence"):
        """
        Initialize the ToxicLanguageValidator with specified parameters.

        Args:
            threshold (float): The threshold for detecting toxic language.
            validation_method (str): The method used for validation.
        """
        self.threshold = threshold
        self.validation_method = validation_method
        self.guard = self.setup_guard()

    def setup_guard(self):
        """
        Setup and configure the Guard object with the ToxicLanguage validator.

        Returns:
            Guard: Configured Guard object.
        """
        guard = Guard().use(
            ToxicLanguage,
            threshold=self.threshold,
            validation_method=self.validation_method,
            on_fail="exception"
        )
        return guard

    def validate_sentence(self, sentence):
        """
        Validate a sentence for toxic language using the configured Guard object.

        Args:
            sentence (str): The sentence to be validated.

        Returns:
            str: Success message if validation passes.

        Raises:
            Exception: If validation fails, indicating toxic content detected.
        """
        try:
            self.guard.validate(sentence)
            return "Validation passed: Sentence is considered non-toxic."
        except Exception as e:
            raise Exception(f"Validation failed: {str(e)}")

# Main function to test the functionality
def main():
    validator = ToxicLanguageValidator()

    # Testing different validations
    try:
        print(validator.validate_sentence("Love how you think and attack the problem. Great job!"))
        print(validator.validate_sentence("Please look carefully. You are a stupid idiot who can't do anything right."))
    except Exception as error:
        print(error)

# Run the main function if this script is executed
if __name__ == "__main__":
    main()
# Out:
# Validation passed: Sentence is considered non-toxic.
# Validation failed: Validation failed for field with errors: The following sentences in your response were found to be toxic:
#
# - You are a stupid idiot who can't do anything right.

# %% [markdown]
# ##Brand Damage

# %%
# !guardrails hub install hub://guardrails/competitor_check
# Out:
# Installing hub://guardrails/competitor_check...
# [=   ] Fetching manifest
# [    ] Downloading dependencies  Running command git clone --filter=blob:none --quiet https://github.com/guardrails-ai/competitor_check.git /tmp/pip-req-build-qgtezzq8
# [====] Downloading dependencies
# [   =] Running post-install setup
# ✅Successfully installed guardrails/competitor_check!
#
#
# Import validator:
# from guardrails.hub import CompetitorCheck
#
# Get more info:
# https://hub.guardrailsai.com/validator/guardrails/competitor_check

# %%
# Import Guard and Validator
from guardrails import Guard
from guardrails.hub import CompetitorCheck


# Setup Guard
guard = Guard().use(CompetitorCheck, ["Apple", "Samsung"], "exception")

response = guard.validate(
    "The apple doesn't fall far from the tree."
)  # Validator passes

try:
    response = guard.validate("Apple just released a new iPhone.")  # Validator fails
except Exception as e:
    print(e)
# Out:
# /usr/local/lib/python3.10/dist-packages/guardrails/validators/__init__.py:51: FutureWarning:
#     Importing validators from `guardrails.validators` is deprecated.
#     All validators are now available in the Guardrails Hub. Please install
#     and import them from the hub instead. All validators will be
#     removed from this module in the next major release.
#
#     Install with: `guardrails hub install hub://<namespace>/<validator_name>`
#     Import as: from guardrails.hub import `ValidatorName`
#
#   warn(
# Validation failed for field with errors: Found the following competitors: [['Apple']]. Please avoid naming those competitors next time

# %%
# Import necessary modules and validators
from guardrails import Guard
from guardrails.hub import CompetitorCheck

class CompetitorValidator:
    def __init__(self, competitors):
        """
        Initialize the CompetitorValidator with a list of competitors.

        Args:
            competitors (list): A list of competitor names to monitor.
        """
        self.competitors = competitors
        self.guard = self.setup_guard()

    def setup_guard(self):
        """
        Setup and configure the Guard object with the CompetitorCheck validator.

        Returns:
            Guard: Configured Guard object with CompetitorCheck configured to raise an exception on failure.
        """
        guard = Guard().use(
            CompetitorCheck,
            self.competitors,
            on_fail="exception"
        )
        return guard

    def validate_text(self, text):
        """
        Validate a piece of text to check for mentions of competitors.

        Args:
            text (str): The text to be validated.

        Returns:
            str: Success message if validation passes.

        Raises:
            Exception: If the text mentions competitors, indicating a validation failure.
        """
        try:
            self.guard.validate(text)
            return "Validation passed: Text does not improperly mention competitors."
        except Exception as e:
            raise Exception(f"Validation failed: {str(e)}")

# Main function to test the functionality
def main():
    validator = CompetitorValidator(["Apple", "Samsung"])

    # Testing different text inputs
    try:
        print(validator.validate_text("The apple doesn't fall far from the tree."))
        print(validator.validate_text("Apple just released a new iPhone."))
    except Exception as error:
        print(error)

# Run the main function if this script is executed
if __name__ == "__main__":
    main()
# Out:
# Validation passed: Text does not improperly mention competitors.
# Validation failed: Validation failed for field with errors: Found the following competitors: [['Apple']]. Please avoid naming those competitors next time

# %%
import os

# Set the environment variable for OpenAI API key
os.environ['OPENAI_API_KEY'] = ''

# %%
# !guardrails hub install hub://guardrails/wiki_provenance
# !guardrails hub install hub://reflex/valid_python
# !guardrails hub install hub://guardrails/toxic_language
# !guardrails hub install hub://guardrails/competitor_check
# Out:
# Installing hub://guardrails/wiki_provenance...
# [=== ] Fetching manifest
# [    ] Downloading dependencies  Running command git clone --filter=blob:none --quiet https://github.com/guardrails-ai/wiki_provenance.git /tmp/pip-req-build-6_dsfw9u
# [   =] Downloading dependenciesWARNING: Target directory /usr/local/lib/python3.10/dist-packages/guardrails/hub/guardrails/wiki_provenance/wiki_provenance-0.0.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /usr/local/lib/python3.10/dist-packages/guardrails/hub/guardrails/wiki_provenance/validator already exists. Specify --upgrade to force replacement.
# [    ] Downloading dependenciesERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastapi-cli 0.0.4 requires typer>=0.12.3, but you have typer 0.9.4 which is incompatible.
# [=   ] Downloading dependencies
# [   =] Running post-install setupERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# guardrails-ai 0.4.5 requires typer[all]<0.10.0,>=0.9.0, but you have typer 0.12.3 which is incompatible.
# [=   ] Running post-install setup
# ✅Successfully installed guardrails/wiki_provenance!
#
#
# Import validator:
# from guardrails.hub import WikiProvenance
#
# Get more info:
# https://hub.guardrailsai.com/validator/guardrails/wiki_provenance
#
# Installing hub://reflex/valid_python...
# [    ] Fetching manifest
# [    ] Downloading dependencies  Running command git clone --filter=blob:none --quiet https://github.com/reflex-dev/valid_python_validator.git /tmp/pip-req-build-fcs5azzp
# [   =] Downloading dependenciesERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastapi-cli 0.0.4 requires typer>=0.12.3, but you have typer 0.9.4 which is incompatible.
# [=   ] Downloading dependencies
# [    ] Running post-install setup
# ✅Successfully installed reflex/valid_python!
#
#
# Import validator:
# from guardrails.hub import ValidPython
#
# Get more info:
# https://hub.guardrailsai.com/validator/reflex/valid_python
#
# Installing hub://guardrails/toxic_language...
# [   =] Fetching manifest
# [    ] Downloading dependencies  Running command git clone --filter=blob:none --quiet https://github.com/guardrails-ai/toxic_language.git /tmp/pip-req-build-_93p5yii
# [    ] Downloading dependencies
# [====] Running post-install setupDownloading: "https://github.com/unitaryai/detoxify/releases/download/v0.1.2/unbiased-albert-c8519128.ckpt" to /root/.cache/torch/hub/checkpoints/unbiased-albert-c8519128.ckpt
# 100% 44.6M/44.6M [00:00<00:00, 209MB/s]
# [  ==] Running post-install setup/usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json: 100% 684/684 [00:00<00:00, 3.75MB/s]
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 153kB/s]
# spiece.model: 100% 760k/760k [00:00<00:00, 7.92MB/s]
# tokenizer.json: 100% 1.31M/1.31M [00:00<00:00, 14.5MB/s]
# [   =] Running post-install setup
# ✅Successfully installed guardrails/toxic_language!
#
#
# Import validator:
# from guardrails.hub import ToxicLanguage
#
# Get more info:
# https://hub.guardrailsai.com/validator/guardrails/toxic_language
#
# Installing hub://guardrails/competitor_check...
# [=   ] Fetching manifest
# [  ==] Downloading dependencies  Running command git clone --filter=blob:none --quiet https://github.com/guardrails-ai/competitor_check.git /tmp/pip-req-build-f5o94y5v
# [ ===] Downloading dependencies
# [=== ] Running post-install setup
# ✅Successfully installed guardrails/competitor_check!
#
#
# Import validator:
# from guardrails.hub import CompetitorCheck
#
# Get more info:
# https://hub.guardrailsai.com/validator/guardrails/competitor_check

# %%
from guardrails.hub import WikiProvenance
from guardrails.hub import ValidPython
from guardrails.hub import ToxicLanguage
from guardrails.hub import CompetitorCheck
from guardrails import Guard

# %% [markdown]
# ##Unified all four output guardrails

# %%
class UnifiedValidator:
    def __init__(self):
        """Initialize the Guard with multiple validators."""
        self.guard = Guard().use(
            WikiProvenance,
            topic_name="Apple company",
            validation_method="sentence",
            llm_callable="gpt-3.5-turbo",
            on_fail="exception"
        ).use(
            ValidPython,
            on_fail="exception"
        ).use(
            ToxicLanguage,
            threshold=0.5,
            validation_method="sentence",
            on_fail="exception"
        ).use(
            CompetitorCheck,
            ["Apple", "Samsung"],
            on_fail="exception"
        )

    def validate_input(self, input_data, data_type):
        """
        Validate the input data based on the type of data provided.

        Args:
            input_data (str): The input data to be validated.
            data_type (str): Type of data to validate ('wiki', 'python', 'toxic', 'competitor').

        Returns:
            str: Success message if validation passes.

        Raises:
            Exception: If any validation fails.
        """
        try:
            if data_type == 'wiki':
                return self.guard.validate(input_data, metadata={"pass_on_invalid": True})  # WikiProvenance
            elif data_type == 'python':
                return self.guard.validate(input_data)  # ValidPython
            elif data_type == 'toxic':
                return self.guard.validate(input_data)  # ToxicLanguage
            elif data_type == 'competitor':
                return self.guard.validate(input_data)  # CompetitorCheck
            else:
                raise ValueError("Unknown validation type provided")
        except Exception as e:
            raise Exception(f"Validation failed for {data_type}: {str(e)}")

# Usage example in Google Colab or any Python environment
if __name__ == "__main__":
    validator = UnifiedValidator()

    # Testing different validations
    try:
        print(validator.validate_input("Apple was founded by Steve Jobs in April 1976.", 'wiki'))
        print(validator.validate_input("def foo():\n  print('Hello World')", 'python'))
        print(validator.validate_input("Love how you think and attack the problem. Great job!", 'toxic'))
        print(validator.validate_input("Apple just released a new iPhone.", 'competitor'))
    except Exception as error:
        print(error)
# Out:
# Search results:
#  ['Apple Inc.', 'Gold Apple (company)', 'Apple Store']
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 0-7527489502388850348
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 1-5549756118836671997
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 2--3569849298414699135
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 3-1528365899215430754
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 4-1969106076837230050
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 5-2147372421406710463
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 6-8245596100879937084
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 7--640114694469836140
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 8--8129640673853793882
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 9-2116053992050025711
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 10--7915732023792137820
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 11-5495111213643671274
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 12-3190719156455444406
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 13-1452603214101813861
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 14-1001398223542050281
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 15-627023781011546220
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 16-7582272266364025919
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 17--7684909974526908210
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 18-6461195805404956641
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 19-2765812911121094453
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 20-5483528750714078050
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 21-6813554008762493153
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 22-8438172907698186663
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 23-8237966058449759504
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 24--511365666340893516
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 25--477257521306826513
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 26-5051972721284116739
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 27--6341873103682433001
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 28--6398674615613387472
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 29-9075866008622601630
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 30--7198940055007620487
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 31--6679140956885323392
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 32-3227576842614399801
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 33--9146971691019050022
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 34--1731238515712023485
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 35--3766298117456602781
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 36--4242264260698567966
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 37-761304190289378085
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 38-2078915538324900663
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 39-5628735384453107806
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 40-8053419309359261596
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 41-1945160385820498789
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: 42--703618236756272062
# WARNING:chromadb.segment.impl.vector.local_hnsw:Add of existing embedding ID: